# %% [markdown]
# # Project Plan
#
# Outline the steps in your project and who is responsible for each component. You will use this file to organize and keep track of progress.
#
# Glynn:
# - Initial data exploration for census data on the diversity of different universities across the country
#     - Narrow dataset to 2021-2022 and 2022-2023 school year
#     - Narrow dataset down to key and control variables
#     - For each university, create a measure for racial homogeneity, and variables that give the pct composition of each university
# - Map universities with color coded dots corresponding to racial homogeneity
# - Create some kind of faceted visualization for the pct of a university of a particular racial group and the earning outcomes
# - Run regression
#
#
# David:
# - Explore the census data by county.
# - Variables for diversity.
# - Calculate data for racial homogeneity using the formulas from Glynn's data.
# - Create a spatial joint for Glynn's data on colleges and census data.
#
# Jenna:
# - Conducted initial data exploration of NCAA scholarship data and raw racial demographic reporting
# - Cleaned and consolidated data into a single spreadsheet compiling conference, division level, and racial makeup across athletic programs
# - Merged median earnings data from the Department of Education with NCAA athletic scholarship data to create a unified dataset
# - Developed visualizations displaying median earnings averages across Division I, II, and III
# - Built regression model visualizations examining racial proportion trends across division levels
