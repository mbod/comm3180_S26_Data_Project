# %% [markdown]
# # Diversity by County
# This notebook intends to anlayze the racial composition data of each county to create a condensed dataframe that can consequently be used in further comparison and analysis.

# %% [markdown]
# # Clean data
# Merge the column with the data dictionary + merge multiracial categories.

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import re
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity

# %%
racial_census_df = pd.read_csv('../data/racialcensusdata.csv')

# %%
racial_census_df.head(5)
# Out:
#            GEO_ID                     NAME    P9_001N  \
# 0       Geography     Geographic Area Name   !!Total:
# 1  0500000US01001  Autauga County, Alabama      58805
# 2  0500000US01003  Baldwin County, Alabama     231767
# 3  0500000US01005  Barbour County, Alabama      25223
# 4  0500000US01007     Bibb County, Alabama      22293
#
#                          P9_002N                             P9_003N  \
# 0   !!Total:!!Hispanic or Latino   !!Total:!!Not Hispanic or Latino:
# 1                           2117                               56688
# 2                          12686                              219081
# 3                           1510                               23713
# 4                            740                               21553
#
#                                              P9_004N  \
# 0   !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                              54198
# 2                                             208713
# 3                                              23160
# 4                                              20953
#
#                                              P9_005N  \
# 0   !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                              41582
# 2                                             186495
# 3                                              11086
# 4                                              16442
#
#                                              P9_006N  \
# 0   !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                              11352
# 2                                              18001
# 3                                              11850
# 4                                               4390
#
#                                              P9_007N  \
# 0   !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                                184
# 2                                               1291
# 3                                                 58
# 4                                                 39
#
#                                              P9_008N  ...  \
# 0   !!Total:!!Not Hispanic or Latino:!!Population...  ...
# 1                                                873  ...
# 2                                               2029  ...
# 3                                                103  ...
# 4                                                 26  ...
#
#                                              P9_065N  \
# 0   !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                                  0
# 2                                                  0
# 3                                                  2
# 4                                                  0
#
#                                              P9_066N  \
# 0   !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                                  0
# 2                                                  0
# 3                                                  2
# 4                                                  0
#
#                                              P9_067N  \
# 0   !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#                                              P9_068N  \
# 0   !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#                                              P9_069N  \
# 0   !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#                                              P9_070N  \
# 0   !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#                                              P9_071N  \
# 0   !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#                                              P9_072N  \
# 0   !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#                                              P9_073N Unnamed: 75
# 0   !!Total:!!Not Hispanic or Latino:!!Population...         NaN
# 1                                                  0         NaN
# 2                                                  0         NaN
# 3                                                  0         NaN
# 4                                                  0         NaN
#
# [5 rows x 76 columns]

# %%
df_subset = racial_census_df.iloc[:, :13].copy()

# %%
df_subset
# Out:
#               GEO_ID                              NAME    P9_001N  \
# 0          Geography              Geographic Area Name   !!Total:
# 1     0500000US01001           Autauga County, Alabama      58805
# 2     0500000US01003           Baldwin County, Alabama     231767
# 3     0500000US01005           Barbour County, Alabama      25223
# 4     0500000US01007              Bibb County, Alabama      22293
# ...              ...                               ...        ...
# 3217  0500000US72145  Vega Baja Municipio, Puerto Rico      54414
# 3218  0500000US72147    Vieques Municipio, Puerto Rico       8249
# 3219  0500000US72149   Villalba Municipio, Puerto Rico      22093
# 3220  0500000US72151    Yabucoa Municipio, Puerto Rico      30426
# 3221  0500000US72153      Yauco Municipio, Puerto Rico      34172
#
#                             P9_002N                             P9_003N  \
# 0      !!Total:!!Hispanic or Latino   !!Total:!!Not Hispanic or Latino:
# 1                              2117                               56688
# 2                             12686                              219081
# 3                              1510                               23713
# 4                               740                               21553
# ...                             ...                                 ...
# 3217                          54012                                 402
# 3218                           7586                                 663
# 3219                          22008                                  85
# 3220                          30258                                 168
# 3221                          33982                                 190
#
#                                                 P9_004N  \
# 0      !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                                 54198
# 2                                                208713
# 3                                                 23160
# 4                                                 20953
# ...                                                 ...
# 3217                                                353
# 3218                                                653
# 3219                                                 80
# 3220                                                156
# 3221                                                177
#
#                                                 P9_005N  \
# 0      !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                                 41582
# 2                                                186495
# 3                                                 11086
# 4                                                 16442
# ...                                                 ...
# 3217                                                279
# 3218                                                533
# 3219                                                 65
# 3220                                                115
# 3221                                                136
#
#                                                 P9_006N  \
# 0      !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                                 11352
# 2                                                 18001
# 3                                                 11850
# 4                                                  4390
# ...                                                 ...
# 3217                                                 31
# 3218                                                 47
# 3219                                                  3
# 3220                                                 12
# 3221                                                 11
#
#                                                 P9_007N  \
# 0      !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                                   184
# 2                                                  1291
# 3                                                    58
# 4                                                    39
# ...                                                 ...
# 3217                                                  9
# 3218                                                 15
# 3219                                                  5
# 3220                                                  1
# 3221                                                  3
#
#                                                 P9_008N  \
# 0      !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                                   873
# 2                                                  2029
# 3                                                   103
# 4                                                    26
# ...                                                 ...
# 3217                                                 11
# 3218                                                  3
# 3219                                                  1
# 3220                                                  8
# 3221                                                 15
#
#                                                 P9_009N  \
# 0      !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                                    22
# 2                                                   122
# 3                                                     0
# 4                                                     9
# ...                                                 ...
# 3217                                                  0
# 3218                                                  0
# 3219                                                  0
# 3220                                                  2
# 3221                                                  2
#
#                                                 P9_010N  \
# 0      !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                                   185
# 2                                                   775
# 3                                                    63
# 4                                                    47
# ...                                                 ...
# 3217                                                 23
# 3218                                                 55
# 3219                                                  6
# 3220                                                 18
# 3221                                                 10
#
#                                                 P9_011N
# 0      !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                                  2490
# 2                                                 10368
# 3                                                   553
# 4                                                   600
# ...                                                 ...
# 3217                                                 49
# 3218                                                 10
# 3219                                                  5
# 3220                                                 12
# 3221                                                 13
#
# [3222 rows x 13 columns]

# %% [markdown]
# The name of the columns might be confusing since they are based on markers from the census data base, i.e. P9_004N, what does that mean? We might want tó change the dataframe so that the column names are more useful.

# %%
# Create a dictionary mapping the current index to a clean name
new_names = {
    df_subset.columns[0]: 'GEO_ID',
    df_subset.columns[1]: 'County_Name',
    df_subset.columns[2]: 'Total_Pop',
    df_subset.columns[3]: 'Hispanic_Latino',
    df_subset.columns[4]: 'Not_Hispanic_Total',
    df_subset.columns[5]: 'One_Race_Total',
    df_subset.columns[6]: 'White_alone',
    df_subset.columns[7]: 'Black_alone',
    df_subset.columns[8]: 'AIAN_alone',   # American Indian / Alaska Native
    df_subset.columns[9]: 'Asian_alone',
    df_subset.columns[10]: 'NHPI_alone',  # Native Hawaiian / Pacific Islander
    df_subset.columns[11]: 'Other_alone',
    df_subset.columns[12]: 'Two_or_More'  # This is the multiracial category
}

# Apply the rename
df_subset = df_subset.drop(0).reset_index(drop=True)
df_subset = df_subset.rename(columns=new_names)


# Make sure the numbers are actually numbers (int) for analysis
cols_to_fix = df_subset.columns[2:]
df_subset[cols_to_fix] = df_subset[cols_to_fix].apply(pd.to_numeric)

df_subset.head()
# Out:
#            GEO_ID              County_Name  Total_Pop  Hispanic_Latino  \
# 0  0500000US01001  Autauga County, Alabama      58805             2117
# 1  0500000US01003  Baldwin County, Alabama     231767            12686
# 2  0500000US01005  Barbour County, Alabama      25223             1510
# 3  0500000US01007     Bibb County, Alabama      22293              740
# 4  0500000US01009   Blount County, Alabama      59134             5771
#
#    Not_Hispanic_Total  One_Race_Total  White_alone  Black_alone  AIAN_alone  \
# 0               56688           54198        41582        11352         184
# 1              219081          208713       186495        18001        1291
# 2               23713           23160        11086        11850          58
# 3               21553           20953        16442         4390          39
# 4               53363           51063        49764          826         188
#
#    Asian_alone  NHPI_alone  Other_alone  Two_or_More
# 0          873          22          185         2490
# 1         2029         122          775        10368
# 2          103           0           63          553
# 3           26           9           47          600
# 4          174          11          100         2300

# %% [markdown]
# Now that we have more useful names and we have the columns that will help us establish the racial composition, we want to store this data in a manageable way. Since we are trying to conduct a similarity analysis later on, we want to place this information in a vector form.

# %%
# 1. Define the columns that make up the 100% total population
race_columns = ['Hispanic_Latino', 'White_alone', 'Black_alone', 'AIAN_alone', 
                'Asian_alone', 'NHPI_alone', 'Other_alone', 'Two_or_More']

# 2. Calculate proportions by dividing the race columns by Total_Pop
df_proportions = df_subset[race_columns].div(df_subset['Total_Pop'], axis=0).round(4)

# 3. Create new vector dataframe
df_vectors = df_subset[['GEO_ID', 'County_Name']].copy()

# 4. Store these proportions as a vector
df_vectors['race_proportion_vector'] = df_proportions.values.tolist()

df_vectors.head()
# Out:
#            GEO_ID              County_Name  \
# 0  0500000US01001  Autauga County, Alabama
# 1  0500000US01003  Baldwin County, Alabama
# 2  0500000US01005  Barbour County, Alabama
# 3  0500000US01007     Bibb County, Alabama
# 4  0500000US01009   Blount County, Alabama
#
#                               race_proportion_vector
# 0  [0.036, 0.7071, 0.193, 0.0031, 0.0148, 0.0004,...
# 1  [0.0547, 0.8047, 0.0777, 0.0056, 0.0088, 0.000...
# 2  [0.0599, 0.4395, 0.4698, 0.0023, 0.0041, 0.0, ...
# 3  [0.0332, 0.7375, 0.1969, 0.0017, 0.0012, 0.000...
# 4  [0.0976, 0.8415, 0.014, 0.0032, 0.0029, 0.0002...

# %% [markdown]
# Now, we also want to calculate the diversity index via a sum of squares of the racial proportions

# %%
# 1. Calculate the sum of squares for each row in the proportions dataframe
df_vectors['diversity_index'] = (df_proportions ** 2).sum(axis=1).round(4)

df_vectors.head()
# Out:
#            GEO_ID              County_Name  \
# 0  0500000US01001  Autauga County, Alabama
# 1  0500000US01003  Baldwin County, Alabama
# 2  0500000US01005  Barbour County, Alabama
# 3  0500000US01007     Bibb County, Alabama
# 4  0500000US01009   Blount County, Alabama
#
#                               race_proportion_vector  diversity_index
# 0  [0.036, 0.7071, 0.193, 0.0031, 0.0148, 0.0004,...           0.5406
# 1  [0.0547, 0.8047, 0.0777, 0.0056, 0.0088, 0.000...           0.6587
# 2  [0.0599, 0.4395, 0.4698, 0.0023, 0.0041, 0.0, ...           0.4180
# 3  [0.0332, 0.7375, 0.1969, 0.0017, 0.0012, 0.000...           0.5845
# 4  [0.0976, 0.8415, 0.014, 0.0032, 0.0029, 0.0002...           0.7194

# %% [markdown]
# We want to compare these diversity indicators to the ones present at the state level. As such, we need to conduct a similar manipulation to obtain the diversity index and racial composition vector of each state

# %%
# Extract the 2-digit state code from GEO_ID
df_subset['State_FIPS'] = df_subset['GEO_ID'].str[9:11]

# %%
# 1. Group by state and sum the raw counts
df_state_raw = df_subset.groupby('State_FIPS')[['Total_Pop'] + race_columns].sum()

# 2. Calculate proportions (divide each race sum by the state total population)
df_state_props = df_state_raw[race_columns].div(df_state_raw['Total_Pop'], axis=0).round(4)

# 3. Add the Diversity Index (Sum of Squares)
df_state_props['diversity_index'] = (df_state_props ** 2).sum(axis=1).round(4)

# 4. Store as vectors
df_state_props['state_vector'] = df_state_props[race_columns].values.tolist()

df_state_props.head()
# Out:
#             Hispanic_Latino  White_alone  Black_alone  AIAN_alone  \
# State_FIPS
# 01                   0.0526       0.6312       0.2564      0.0046
# 02                   0.0679       0.5751       0.0283      0.1484
# 04                   0.3065       0.5337       0.0443      0.0369
# 05                   0.0853       0.6852       0.1494      0.0068
# 06                   0.3940       0.3469       0.0536      0.0039
#
#             Asian_alone  NHPI_alone  Other_alone  Two_or_More  \
# State_FIPS
# 01               0.0151      0.0005       0.0029       0.0367
# 02               0.0592      0.0170       0.0062       0.0978
# 04               0.0348      0.0020       0.0044       0.0373
# 05               0.0170      0.0047       0.0027       0.0489
# 06               0.1512      0.0035       0.0057       0.0412
#
#             diversity_index                                       state_vector
# State_FIPS
# 01                   0.4685  [0.0526, 0.6312, 0.2564, 0.0046, 0.0151, 0.000...
# 02                   0.3716  [0.0679, 0.5751, 0.0283, 0.1484, 0.0592, 0.017...
# 04                   0.3847  [0.3065, 0.5337, 0.0443, 0.0369, 0.0348, 0.002...
# 05                   0.5019  [0.0853, 0.6852, 0.1494, 0.0068, 0.017, 0.0047...
# 06                   0.3031  [0.394, 0.3469, 0.0536, 0.0039, 0.1512, 0.0035...

# %% [markdown]
# Since a lot of this data is going to be analyzed by multiple people and in different occasions, we want to save the data into our data folder.

# %%
# Store the state data to manipulate with the school data later
df_state_props.to_csv('../data/racial_comp_state.csv', index=True)

# %%
df_state_props.to_pickle('racial_comp_state.pkl')

# %% [markdown]
# Given that we also want to identify whether schools follow diversity trends closer to the federal compostion, we want to calculate these proportions using census data.

# %%
# 1. Sum all counties nationwide
national_totals = df_subset[['Total_Pop'] + race_columns].sum()

# 2. Calculate national proportions
national_proportions = (national_totals[race_columns] / national_totals['Total_Pop']).round(4)

# 3. Calculate national concentration index
national_index = (national_proportions ** 2).sum().round(4)

national_vector = national_proportions.to_numpy()

national_vector
# Out:
# array([0.1952, 0.5728, 0.1193, 0.0067, 0.0586, 0.0019, 0.0051, 0.0405])

# %% [markdown]
# Now that all of our data is stored as vectors, we are now able to conduct a similarity test between the vectors through a cosine similarity formula.

# %%
def calculate_similarity(vec1, vec2):
    v1 = np.array(vec1).reshape(1, -1)
    v2 = np.array(vec2).reshape(1, -1)
    return round(cosine_similarity(v1, v2)[0][0], 4)

# %%
# Dictionary of state vectors
state_vector_lookup = df_state_props['state_vector'].to_dict()

# Add a column to df_vectors that identifies the state FIPS
df_vectors['State_FIPS'] = df_vectors['GEO_ID'].str[9:11]

# %%
# 1. Calculate Similarity to National
df_vectors['similarity_to_national'] = df_vectors['race_proportion_vector'].apply(
    lambda x: calculate_similarity(x, national_vector)
)

# 2. Calculate Similarity to State
df_vectors['similarity_to_state'] = df_vectors.apply(
    lambda row: calculate_similarity(row['race_proportion_vector'], 
                                     state_vector_lookup.get(row['State_FIPS'])), 
    axis=1
)

df_vectors.head()
# Out:
#            GEO_ID              County_Name  \
# 0  0500000US01001  Autauga County, Alabama
# 1  0500000US01003  Baldwin County, Alabama
# 2  0500000US01005  Barbour County, Alabama
# 3  0500000US01007     Bibb County, Alabama
# 4  0500000US01009   Blount County, Alabama
#
#                               race_proportion_vector  diversity_index  \
# 0  [0.036, 0.7071, 0.193, 0.0031, 0.0148, 0.0004,...           0.5406
# 1  [0.0547, 0.8047, 0.0777, 0.0056, 0.0088, 0.000...           0.6587
# 2  [0.0599, 0.4395, 0.4698, 0.0023, 0.0041, 0.0, ...           0.4180
# 3  [0.0332, 0.7375, 0.1969, 0.0017, 0.0012, 0.000...           0.5845
# 4  [0.0976, 0.8415, 0.014, 0.0032, 0.0029, 0.0002...           0.7194
#
#   State_FIPS  similarity_to_national  similarity_to_state
# 0         01                  0.9587               0.9925
# 1         01                  0.9589               0.9586
# 2         01                  0.7987               0.9082
# 3         01                  0.9555               0.9913
# 4         01                  0.9579               0.9325

# %%
# Create a 5-digit FIPS column to match standard mapping files
df_vectors['FIPS'] = df_vectors['GEO_ID'].str[-5:]

# %% [markdown]
# To get a sense of what we have been doing, we want to map some of the results.

# %%
# 1. Download the County boundaries
url = "https://www2.census.gov/geo/tiger/GENZ2021/shp/cb_2021_us_county_5m.zip"
counties_map = gpd.read_file(url)

# 2. Join the index data to the map
merged_map = counties_map.merge(df_vectors, left_on='GEOID', right_on='FIPS')

# 3. Filter for a specific state if needed
# Example: Alabama (FIPS starts with '01') or Pennsylvania (starts with '42')
state_map = merged_map[merged_map['STATEFP'] == '08'] # Change '01' to '42' for PA

# %%
# Create the plot
fig, ax = plt.subplots(1, 1, figsize=(12, 8))

state_map.plot(column='diversity_index', 
               cmap='YlOrRd_r',  # Yellow to Orange to Red (Red = More Concentrated)
               legend=True,
               legend_kwds={'label': "Racial Concentration Index (Sum of Squares)"},
               ax=ax,
               edgecolor='black',
               linewidth=0.2)

ax.set_title('Heatmap of Racial Concentration by County', fontsize=15)
ax.axis('off')

plt.show()

# %% [markdown]
# Using this racial diversity index, we see that counties with darker colors are more diverse while more yellow counties are more homogenous.

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 10))

# Plot the map
merged_map.plot(column='diversity_index', 
               cmap='YlOrRd_r', 
               legend=True,
               ax=ax,
               edgecolor='black',
               linewidth=0.1)

# ZOOM into the contiguous United States
ax.set_xlim([-130, -65]) # Longitude
ax.set_ylim([23, 50])    # Latitude

ax.set_title('National Racial Concentration Index', fontsize=20)
ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# Looking at the nationwide data, there are a few outliers that are important to point out. In some cases the homogeneity of the county does not come from a white majority. For example, in Texan counties near the Mexican border we have places that are primarily Latino.

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 10))

# Plot the map
merged_map.plot(column='similarity_to_national', 
               cmap='plasma', 
               legend=True,
               ax=ax,
               edgecolor='black',
               linewidth=0.1)

# ZOOM into the contiguous United States
ax.set_xlim([-130, -65]) # Longitude
ax.set_ylim([23, 50])    # Latitude

ax.set_title('Similarity to National Racial Diversity', fontsize=20)
ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# In the same way, counties in these areas are more likely to be more drastically different than the national racial composition. In this case, counties that are within a Native American reservation also have a bigger discrepancy.

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 10))

# Plot the map
merged_map.plot(column='similarity_to_state', 
               cmap='magma', 
               legend=True,
               ax=ax,
               edgecolor='black',
               linewidth=0.1)

# ZOOM into the contiguous United States
ax.set_xlim([-130, -65]) # Longitude
ax.set_ylim([23, 50])    # Latitude

ax.set_title('Similarity to State Racial Diversity', fontsize=20)
ax.axis('off')

plt.tight_layout()
plt.show()

# %%
merged_map
# Out:
#      STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID          NAME  \
# 0         01      059  00161555  0500000US01059  01059      Franklin
# 1         06      057  01682927  0500000US06057  06057        Nevada
# 2         26      031  01622958  0500000US26031  26031     Cheboygan
# 3         29      119  00758518  0500000US29119  29119      McDonald
# 4         31      157  00835900  0500000US31157  31157  Scotts Bluff
# ...      ...      ...       ...             ...    ...           ...
# 3216      13      301  00347777  0500000US13301  13301        Warren
# 3217      06      023  01681908  0500000US06023  06023      Humboldt
# 3218      34      023  00882230  0500000US34023  34023     Middlesex
# 3219      13      311  00326781  0500000US13311  13311         White
# 3220      13      189  00348794  0500000US13189  13189      McDuffie
#
#                  NAMELSAD STUSPS  STATE_NAME LSAD  ...      AWATER  \
# 0         Franklin County     AL     Alabama   06  ...    32639621
# 1           Nevada County     CA  California   06  ...    41531993
# 2        Cheboygan County     MI    Michigan   06  ...   440607445
# 3         McDonald County     MO    Missouri   06  ...      520251
# 4     Scotts Bluff County     NE    Nebraska   06  ...    15402683
# ...                   ...    ...         ...  ...  ...         ...
# 3216        Warren County     GA     Georgia   06  ...     6034478
# 3217      Humboldt County     CA  California   06  ...  1253726036
# 3218     Middlesex County     NJ  New Jersey   06  ...    35291196
# 3219         White County     GA     Georgia   06  ...     3917258
# 3220      McDuffie County     GA     Georgia   06  ...    23114032
#
#                                                geometry          GEO_ID  \
# 0     POLYGON ((-88.16591 34.38093, -88.16563 34.383...  0500000US01059
# 1     POLYGON ((-121.27953 39.23054, -121.25918 39.2...  0500000US06057
# 2     POLYGON ((-84.73269 45.28938, -84.73239 45.787...  0500000US26031
# 3     POLYGON ((-94.61831 36.76656, -94.0689 36.7478...  0500000US29119
# 4     POLYGON ((-104.05293 41.90614, -104.05299 41.9...  0500000US31157
# ...                                                 ...             ...
# 3216  POLYGON ((-82.8666 33.4666, -82.82314 33.50408...  0500000US13301
# 3217  POLYGON ((-124.4086 40.4432, -124.39664 40.462...  0500000US06023
# 3218  POLYGON ((-74.6306 40.3396, -74.62024 40.37375...  0500000US34023
# 3219  POLYGON ((-83.8712 34.6649, -83.87251 34.68309...  0500000US13311
# 3220  POLYGON ((-82.64352 33.61803, -82.6335 33.6111...  0500000US13189
#
#                         County_Name  \
# 0          Franklin County, Alabama
# 1         Nevada County, California
# 2        Cheboygan County, Michigan
# 3         McDonald County, Missouri
# 4     Scotts Bluff County, Nebraska
# ...                             ...
# 3216         Warren County, Georgia
# 3217    Humboldt County, California
# 3218   Middlesex County, New Jersey
# 3219          White County, Georgia
# 3220       McDuffie County, Georgia
#
#                                  race_proportion_vector diversity_index  \
# 0     [0.1949, 0.7343, 0.0355, 0.004, 0.0021, 0.0001...          0.5792
# 1     [0.1019, 0.8099, 0.0041, 0.0068, 0.0134, 0.001...          0.6698
# 2     [0.0133, 0.8942, 0.0035, 0.0269, 0.0033, 0.0, ...          0.8037
# 3     [0.1209, 0.7152, 0.0181, 0.0212, 0.0161, 0.037...          0.5331
# 4     [0.2273, 0.7125, 0.0065, 0.0129, 0.0077, 0.000...          0.5605
# ...                                                 ...             ...
# 3216  [0.0102, 0.3785, 0.5843, 0.0035, 0.0029, 0.000...          0.4851
# 3217  [0.1358, 0.6838, 0.0127, 0.0546, 0.0256, 0.003...          0.4957
# 3218  [0.2244, 0.386, 0.0912, 0.0014, 0.2641, 0.0002...          0.2781
# 3219  [0.0326, 0.8913, 0.0167, 0.0037, 0.0057, 0.0, ...          0.7979
# 3220  [0.0365, 0.5278, 0.3996, 0.0021, 0.0035, 0.000...          0.4404
#
#       State_FIPS similarity_to_national  similarity_to_state   FIPS
# 0             01                 0.9821               0.9289  01059
# 1             06                 0.9592               0.7230  06057
# 2             26                 0.9303               0.9810  26031
# 3             29                 0.9690               0.9855  29119
# 4             31                 0.9788               0.9867  31157
# ...          ...                    ...                  ...    ...
# 3216          13                 0.6693               0.8875  13301
# 3217          06                 0.9714               0.7706  06023
# 3218          34                 0.8927               0.9321  34023
# 3219          13                 0.9395               0.8538  13311
# 3220          13                 0.8700               0.9852  13189
#
# [3221 rows x 21 columns]

# %%
# Store the merged data to manipulate with the school data later
merged_map.to_csv('../data/racial_comp_county.csv', index=False)

# %% [markdown]
# This notebook does not contain our main analysis but it helped us understand the nature of the index and similarity score that we are looking to observe. The results of this analysis also reminded us to be aware of minority-majority places, especially in schools since some of them are designated as Historically Black Colleges and Universities (HBCU) or Hispanic Serving Institutions (HSI).
